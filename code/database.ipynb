# %% [markdown]
# # Criação do database
# Nessa seção é criado o database contendo as informações de cada dataset filtrado criado na etapa anterior.
# A database será do modelo sqlite3 e é construido a partir de tabelas contendo as informações dos datasets, juntamente com suas relações.

# %% [markdown]
# ## Imports

# %%
from sqlalchemy import create_engine, Table, Column, Integer, String, ForeignKey
from sqlalchemy.orm import sessionmaker, declarative_base, relationship
import pandas as pd
import os

# %%
db_path = "/data.sqlite"
out_path = "../out" #from ./code
basedir = os.path.abspath("../")
init_csv_pattern = "survey_results_20"
end_csv_pattern = "_filtered.csv"

# %%
Base = declarative_base()
engine = create_engine("sqlite:///" + out_path + db_path, echo=True)
Session = sessionmaker(bind=engine)
session = Session()

# %%
class CodingAct(Base):
    __tablename__ = 'codacts'
    
    id = Column(Integer, primary_key=True)
    name = Column(String, unique=True)

class Collab(Base):
    __tablename__ = 'collabs'
    
    id = Column(Integer, primary_key=True)
    name = Column(String, unique=True)

class Database(Base):
    __tablename__ = 'databases'
    
    id = Column(Integer, primary_key=True)
    name = Column(String, unique=True)

class DevType(Base):
    __tablename__ = 'devtypes'
    
    id = Column(Integer, primary_key=True)
    name = Column(String, unique=True)

class Language(Base):
    __tablename__ = 'languages'
    
    id = Column(Integer, primary_key=True)
    name = Column(String, unique=True)

class MiscTech(Base):
    __tablename__ = 'misctechs'
    
    id = Column(Integer, primary_key=True)
    name = Column(String, unique=True)

class OpSys(Base):
    __tablename__ = 'opsys'
    
    id = Column(Integer, primary_key=True)
    name = Column(String, unique=True)

class Platform(Base):
    __tablename__ = 'platforms'
    
    id = Column(Integer, primary_key=True)
    name = Column(String, unique=True)

class WebFrame(Base):
    __tablename__ = 'webframes'
    
    id = Column(Integer, primary_key=True)
    name = Column(String, unique=True)

# %%
# Entry-CodingAct Association
worked_codact_association = Table('worked_codact_association', Base.metadata,
    Column('entry_id', Integer, ForeignKey('entries.id')),
    Column('codact_id', Integer, ForeignKey('codacts.id'))
    )

# Entry-Collab Association
worked_collab_association = Table('worked_collab_association', Base.metadata,
    Column('entry_id', Integer, ForeignKey('entries.id')),
    Column('collab_id', Integer, ForeignKey('collabs.id'))
    )
want_collab_association = Table('want_collab_association', Base.metadata,
    Column('entry_id', Integer, ForeignKey('entries.id')),
    Column('collab_id', Integer, ForeignKey('collabs.id'))
    )

# Entry-Database Association
worked_database_association = Table('worked_database_association', Base.metadata,
    Column('entry_id', Integer, ForeignKey('entries.id')),
    Column('database_id', Integer, ForeignKey('databases.id'))
    )
worked_devtype_association = Table('worked_devtype_association', Base.metadata,
    Column('entry_id', Integer, ForeignKey('entries.id')),
    Column('devtype_id', Integer, ForeignKey('devtypes.id'))
    )
want_database_association = Table('want_database_association', Base.metadata,
    Column('entry_id', Integer, ForeignKey('entries.id')),
    Column('database_id', Integer, ForeignKey('databases.id'))
    )
# Entry-Language Association
worked_language_association = Table('worked_language_association', Base.metadata,
    Column('entry_id', Integer, ForeignKey('entries.id')),
    Column('language_id', Integer, ForeignKey('languages.id'))
    )
want_language_association = Table('want_language_association', Base.metadata,
    Column('entry_id', Integer, ForeignKey('entries.id')),
    Column('language_id', Integer, ForeignKey('languages.id'))
    )

# Entry-MiscTech Association
worked_misctech_association = Table('worked_misctech_association', Base.metadata,
    Column('entry_id', Integer, ForeignKey('entries.id')),
    Column('misctech_id', Integer, ForeignKey('misctechs.id'))
    )
want_misctech_association = Table('want_misctechs_association', Base.metadata,
    Column('entry_id', Integer, ForeignKey('entries.id')),
    Column('misctech_id', Integer, ForeignKey('misctechs.id'))
    )

# Entry-OpSys Association
worked_opsys_association = Table('worked_opsys_association', Base.metadata,
    Column('entry_id', Integer, ForeignKey('entries.id')),
    Column('opsys_id', Integer, ForeignKey('opsys.id'))
    )

# Entry-Platform Association
worked_platform_association = Table('worked_platform_association', Base.metadata,
    Column('entry_id', Integer, ForeignKey('entries.id')),
    Column('platform_id', Integer, ForeignKey('platforms.id'))
    )
want_platform_association = Table('want_platform_association', Base.metadata,
    Column('entry_id', Integer, ForeignKey('entries.id')),
    Column('platform_id', Integer, ForeignKey('platforms.id'))
    )

# Entry-WebFrame Association
worked_webframe_association = Table('worked_webframe_association', Base.metadata,
    Column('entry_id', Integer, ForeignKey('entries.id')),
    Column('webframe_id', Integer, ForeignKey('webframes.id'))
    )
want_webframe_association = Table('want_webframe_association', Base.metadata,
    Column('entry_id', Integer, ForeignKey('entries.id')),
    Column('webframe_id', Integer, ForeignKey('webframes.id'))
    )

# %%
class Entry(Base):
    __tablename__ = 'entries'

    id = Column(Integer, primary_key=True)
    year = Column(Integer)
    age = Column(Integer)
    coding_act = relationship("CodingAct", secondary=worked_codact_association, backref="worked_by")
    collab_worked = relationship("Collab", secondary=worked_collab_association, backref="worked_by")
    collab_want = relationship("Collab", secondary=want_collab_association, backref="want_by")
    converted_compy = Column(Integer)
    database_worked = relationship("Database", secondary=worked_database_association, backref="worked_by")
    database_want = relationship("Database", secondary=want_database_association, backref="want_by")
    dev_type = relationship("DevType", secondary=worked_devtype_association, backref="used_by")
    ed_level = Column(String)
    employment = Column(String)
    language_worked = relationship("Language", secondary=worked_language_association, backref="worked_by")
    language_want = relationship("Language", secondary=want_language_association, backref="want_by")
    main_branch = Column(String)
    misc_tech_worked = relationship("MiscTech", secondary=worked_misctech_association, backref="worked_by")
    misc_tech_want = relationship("MiscTech", secondary=want_misctech_association, backref="want_by")
    op_sys = relationship("OpSys", secondary=worked_opsys_association, backref="worked_by")
    org_size = Column(String)
    platform_worked = relationship("Platform", secondary=worked_platform_association, backref="worked_by")
    platform_want = relationship("Platform", secondary=want_platform_association, backref="want_by")
    response_id = Column(Integer)
    webframe_worked = relationship("WebFrame", secondary=worked_webframe_association, backref="worked_by")
    webframe_want = relationship("WebFrame", secondary=want_webframe_association, backref="want_by")
    years_code = Column(String)
    years_codepro = Column(String)

# %% [markdown]
# #### Criar tabelas

# %%
Base.metadata.create_all(engine)
# Out:
# 2023-08-28 22:30:03,469 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-08-28 22:30:03,470 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("codacts")
# 2023-08-28 22:30:03,470 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,471 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("codacts")
# 2023-08-28 22:30:03,472 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,473 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("collabs")
# 2023-08-28 22:30:03,473 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,474 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("collabs")
# 2023-08-28 22:30:03,475 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,476 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("databases")
# 2023-08-28 22:30:03,476 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,477 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("databases")
# 2023-08-28 22:30:03,479 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,480 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("devtypes")
# 2023-08-28 22:30:03,480 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,481 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("devtypes")
# 2023-08-28 22:30:03,482 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,483 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("languages")
# 2023-08-28 22:30:03,483 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,484 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("languages")
# 2023-08-28 22:30:03,485 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,486 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("misctechs")
# 2023-08-28 22:30:03,487 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,488 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("misctechs")
# 2023-08-28 22:30:03,489 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,490 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("opsys")
# 2023-08-28 22:30:03,491 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,492 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("opsys")
# 2023-08-28 22:30:03,493 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,495 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("platforms")
# 2023-08-28 22:30:03,495 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,497 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("platforms")
# 2023-08-28 22:30:03,497 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,499 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("webframes")
# 2023-08-28 22:30:03,500 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,501 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("webframes")
# 2023-08-28 22:30:03,502 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,503 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("worked_codact_association")
# 2023-08-28 22:30:03,504 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,505 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("worked_codact_association")
# 2023-08-28 22:30:03,506 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,507 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("worked_collab_association")
# 2023-08-28 22:30:03,508 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,509 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("worked_collab_association")
# 2023-08-28 22:30:03,510 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,511 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("want_collab_association")
# 2023-08-28 22:30:03,512 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,513 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("want_collab_association")
# 2023-08-28 22:30:03,514 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,515 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("worked_database_association")
# 2023-08-28 22:30:03,516 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,518 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("worked_database_association")
# 2023-08-28 22:30:03,518 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,519 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("worked_devtype_association")
# 2023-08-28 22:30:03,520 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,521 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("worked_devtype_association")
# 2023-08-28 22:30:03,522 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,522 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("want_database_association")
# 2023-08-28 22:30:03,523 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,524 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("want_database_association")
# 2023-08-28 22:30:03,524 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,525 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("worked_language_association")
# 2023-08-28 22:30:03,526 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,527 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("worked_language_association")
# 2023-08-28 22:30:03,528 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,529 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("want_language_association")
# 2023-08-28 22:30:03,530 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,531 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("want_language_association")
# 2023-08-28 22:30:03,532 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,533 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("worked_misctech_association")
# 2023-08-28 22:30:03,534 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,535 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("worked_misctech_association")
# 2023-08-28 22:30:03,536 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,537 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("want_misctechs_association")
# 2023-08-28 22:30:03,537 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,538 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("want_misctechs_association")
# 2023-08-28 22:30:03,539 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,540 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("worked_opsys_association")
# 2023-08-28 22:30:03,540 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,541 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("worked_opsys_association")
# 2023-08-28 22:30:03,542 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,543 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("worked_platform_association")
# 2023-08-28 22:30:03,543 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,545 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("worked_platform_association")
# 2023-08-28 22:30:03,546 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,547 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("want_platform_association")
# 2023-08-28 22:30:03,548 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,550 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("want_platform_association")
# 2023-08-28 22:30:03,550 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,551 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("worked_webframe_association")
# 2023-08-28 22:30:03,552 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,553 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("worked_webframe_association")
# 2023-08-28 22:30:03,553 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,554 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("want_webframe_association")
# 2023-08-28 22:30:03,555 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,556 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("want_webframe_association")
# 2023-08-28 22:30:03,557 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,558 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("entries")
# 2023-08-28 22:30:03,558 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,559 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("entries")
# 2023-08-28 22:30:03,560 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-08-28 22:30:03,561 INFO sqlalchemy.engine.Engine
# CREATE TABLE codacts (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	PRIMARY KEY (id),
# 	UNIQUE (name)
# )
#
#
# 2023-08-28 22:30:03,562 INFO sqlalchemy.engine.Engine [no key 0.00069s] ()
# 2023-08-28 22:30:03,567 INFO sqlalchemy.engine.Engine
# CREATE TABLE collabs (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	PRIMARY KEY (id),
# 	UNIQUE (name)
# )
#
#
# 2023-08-28 22:30:03,568 INFO sqlalchemy.engine.Engine [no key 0.00080s] ()
# 2023-08-28 22:30:03,572 INFO sqlalchemy.engine.Engine
# CREATE TABLE databases (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	PRIMARY KEY (id),
# 	UNIQUE (name)
# )
#
#
# 2023-08-28 22:30:03,573 INFO sqlalchemy.engine.Engine [no key 0.00078s] ()
# 2023-08-28 22:30:03,578 INFO sqlalchemy.engine.Engine
# CREATE TABLE devtypes (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	PRIMARY KEY (id),
# 	UNIQUE (name)
# )
#
#
# 2023-08-28 22:30:03,578 INFO sqlalchemy.engine.Engine [no key 0.00087s] ()
# 2023-08-28 22:30:03,583 INFO sqlalchemy.engine.Engine
# CREATE TABLE languages (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	PRIMARY KEY (id),
# 	UNIQUE (name)
# )
#
#
# 2023-08-28 22:30:03,584 INFO sqlalchemy.engine.Engine [no key 0.00069s] ()
# 2023-08-28 22:30:03,589 INFO sqlalchemy.engine.Engine
# CREATE TABLE misctechs (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	PRIMARY KEY (id),
# 	UNIQUE (name)
# )
#
#
# 2023-08-28 22:30:03,590 INFO sqlalchemy.engine.Engine [no key 0.00060s] ()
# 2023-08-28 22:30:03,594 INFO sqlalchemy.engine.Engine
# CREATE TABLE opsys (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	PRIMARY KEY (id),
# 	UNIQUE (name)
# )
#
#
# 2023-08-28 22:30:03,595 INFO sqlalchemy.engine.Engine [no key 0.00102s] ()
# 2023-08-28 22:30:03,599 INFO sqlalchemy.engine.Engine
# CREATE TABLE platforms (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	PRIMARY KEY (id),
# 	UNIQUE (name)
# )
#
#
# 2023-08-28 22:30:03,600 INFO sqlalchemy.engine.Engine [no key 0.00082s] ()
# 2023-08-28 22:30:03,605 INFO sqlalchemy.engine.Engine
# CREATE TABLE webframes (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	PRIMARY KEY (id),
# 	UNIQUE (name)
# )
#
#
# 2023-08-28 22:30:03,606 INFO sqlalchemy.engine.Engine [no key 0.00057s] ()
# 2023-08-28 22:30:03,611 INFO sqlalchemy.engine.Engine
# CREATE TABLE entries (
# 	id INTEGER NOT NULL,
# 	year INTEGER,
# 	age INTEGER,
# 	converted_compy INTEGER,
# 	ed_level VARCHAR,
# 	employment VARCHAR,
# 	main_branch VARCHAR,
# 	org_size VARCHAR,
# 	response_id INTEGER,
# 	years_code VARCHAR,
# 	years_codepro VARCHAR,
# 	PRIMARY KEY (id)
# )
#
#
# 2023-08-28 22:30:03,612 INFO sqlalchemy.engine.Engine [no key 0.00079s] ()
# 2023-08-28 22:30:03,618 INFO sqlalchemy.engine.Engine
# CREATE TABLE worked_codact_association (
# 	entry_id INTEGER,
# 	codact_id INTEGER,
# 	FOREIGN KEY(entry_id) REFERENCES entries (id),
# 	FOREIGN KEY(codact_id) REFERENCES codacts (id)
# )
#
#
# 2023-08-28 22:30:03,618 INFO sqlalchemy.engine.Engine [no key 0.00057s] ()
# 2023-08-28 22:30:03,622 INFO sqlalchemy.engine.Engine
# CREATE TABLE worked_collab_association (
# 	entry_id INTEGER,
# 	collab_id INTEGER,
# 	FOREIGN KEY(entry_id) REFERENCES entries (id),
# 	FOREIGN KEY(collab_id) REFERENCES collabs (id)
# )
#
#
# 2023-08-28 22:30:03,623 INFO sqlalchemy.engine.Engine [no key 0.00059s] ()
# 2023-08-28 22:30:03,626 INFO sqlalchemy.engine.Engine
# CREATE TABLE want_collab_association (
# 	entry_id INTEGER,
# 	collab_id INTEGER,
# 	FOREIGN KEY(entry_id) REFERENCES entries (id),
# 	FOREIGN KEY(collab_id) REFERENCES collabs (id)
# )
#
#
# 2023-08-28 22:30:03,627 INFO sqlalchemy.engine.Engine [no key 0.00091s] ()
# 2023-08-28 22:30:03,631 INFO sqlalchemy.engine.Engine
# CREATE TABLE worked_database_association (
# 	entry_id INTEGER,
# 	database_id INTEGER,
# 	FOREIGN KEY(entry_id) REFERENCES entries (id),
# 	FOREIGN KEY(database_id) REFERENCES databases (id)
# )
#
#
# 2023-08-28 22:30:03,632 INFO sqlalchemy.engine.Engine [no key 0.00060s] ()
# 2023-08-28 22:30:03,636 INFO sqlalchemy.engine.Engine
# CREATE TABLE worked_devtype_association (
# 	entry_id INTEGER,
# 	devtype_id INTEGER,
# 	FOREIGN KEY(entry_id) REFERENCES entries (id),
# 	FOREIGN KEY(devtype_id) REFERENCES devtypes (id)
# )
#
#
# 2023-08-28 22:30:03,637 INFO sqlalchemy.engine.Engine [no key 0.00060s] ()
# 2023-08-28 22:30:03,641 INFO sqlalchemy.engine.Engine
# CREATE TABLE want_database_association (
# 	entry_id INTEGER,
# 	database_id INTEGER,
# 	FOREIGN KEY(entry_id) REFERENCES entries (id),
# 	FOREIGN KEY(database_id) REFERENCES databases (id)
# )
#
#
# 2023-08-28 22:30:03,641 INFO sqlalchemy.engine.Engine [no key 0.00059s] ()
# 2023-08-28 22:30:03,645 INFO sqlalchemy.engine.Engine
# CREATE TABLE worked_language_association (
# 	entry_id INTEGER,
# 	language_id INTEGER,
# 	FOREIGN KEY(entry_id) REFERENCES entries (id),
# 	FOREIGN KEY(language_id) REFERENCES languages (id)
# )
#
#
# 2023-08-28 22:30:03,646 INFO sqlalchemy.engine.Engine [no key 0.00062s] ()
# 2023-08-28 22:30:03,650 INFO sqlalchemy.engine.Engine
# CREATE TABLE want_language_association (
# 	entry_id INTEGER,
# 	language_id INTEGER,
# 	FOREIGN KEY(entry_id) REFERENCES entries (id),
# 	FOREIGN KEY(language_id) REFERENCES languages (id)
# )
#
#
# 2023-08-28 22:30:03,651 INFO sqlalchemy.engine.Engine [no key 0.00061s] ()
# 2023-08-28 22:30:03,655 INFO sqlalchemy.engine.Engine
# CREATE TABLE worked_misctech_association (
# 	entry_id INTEGER,
# 	misctech_id INTEGER,
# 	FOREIGN KEY(entry_id) REFERENCES entries (id),
# 	FOREIGN KEY(misctech_id) REFERENCES misctechs (id)
# )
#
#
# 2023-08-28 22:30:03,656 INFO sqlalchemy.engine.Engine [no key 0.00062s] ()
# 2023-08-28 22:30:03,660 INFO sqlalchemy.engine.Engine
# CREATE TABLE want_misctechs_association (
# 	entry_id INTEGER,
# 	misctech_id INTEGER,
# 	FOREIGN KEY(entry_id) REFERENCES entries (id),
# 	FOREIGN KEY(misctech_id) REFERENCES misctechs (id)
# )
#
#
# 2023-08-28 22:30:03,661 INFO sqlalchemy.engine.Engine [no key 0.00078s] ()
# 2023-08-28 22:30:03,665 INFO sqlalchemy.engine.Engine
# CREATE TABLE worked_opsys_association (
# 	entry_id INTEGER,
# 	opsys_id INTEGER,
# 	FOREIGN KEY(entry_id) REFERENCES entries (id),
# 	FOREIGN KEY(opsys_id) REFERENCES opsys (id)
# )
#
#
# 2023-08-28 22:30:03,666 INFO sqlalchemy.engine.Engine [no key 0.00077s] ()
# 2023-08-28 22:30:03,670 INFO sqlalchemy.engine.Engine
# CREATE TABLE worked_platform_association (
# 	entry_id INTEGER,
# 	platform_id INTEGER,
# 	FOREIGN KEY(entry_id) REFERENCES entries (id),
# 	FOREIGN KEY(platform_id) REFERENCES platforms (id)
# )
#
#
# 2023-08-28 22:30:03,671 INFO sqlalchemy.engine.Engine [no key 0.00084s] ()
# 2023-08-28 22:30:03,675 INFO sqlalchemy.engine.Engine
# CREATE TABLE want_platform_association (
# 	entry_id INTEGER,
# 	platform_id INTEGER,
# 	FOREIGN KEY(entry_id) REFERENCES entries (id),
# 	FOREIGN KEY(platform_id) REFERENCES platforms (id)
# )
#
#
# 2023-08-28 22:30:03,676 INFO sqlalchemy.engine.Engine [no key 0.00083s] ()
# 2023-08-28 22:30:03,680 INFO sqlalchemy.engine.Engine
# CREATE TABLE worked_webframe_association (
# 	entry_id INTEGER,
# 	webframe_id INTEGER,
# 	FOREIGN KEY(entry_id) REFERENCES entries (id),
# 	FOREIGN KEY(webframe_id) REFERENCES webframes (id)
# )
#
#
# 2023-08-28 22:30:03,680 INFO sqlalchemy.engine.Engine [no key 0.00073s] ()
# 2023-08-28 22:30:03,684 INFO sqlalchemy.engine.Engine
# CREATE TABLE want_webframe_association (
# 	entry_id INTEGER,
# 	webframe_id INTEGER,
# 	FOREIGN KEY(entry_id) REFERENCES entries (id),
# 	FOREIGN KEY(webframe_id) REFERENCES webframes (id)
# )
#
#
# 2023-08-28 22:30:03,685 INFO sqlalchemy.engine.Engine [no key 0.00056s] ()
# 2023-08-28 22:30:03,688 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Inserção dos dados

# %% [markdown]
# ### test

# %%
csv_files = []
for year in range(19, 24):
    csv_files.append([out_path + "/" + init_csv_pattern + str(year) + end_csv_pattern, year + 2000])

# %%
for csv in csv_files:

    data = pd.read_csv(csv[0])
    for index, row in data.iloc[:2].iterrows():
        
        row_items = row["CodingActivities"].split(';') if pd.notnull(row['CodingActivities']) else []
        coding_act_objects = []
        for obj in row_items:
            tb_obj = session.query(CodingAct).filter_by(name=obj).first()
            if obj and not tb_obj:
                tb_obj = CodingAct(name=obj)
                session.add(tb_obj)
            if tb_obj:
                coding_act_objects.append(tb_obj)
    
        row_items = row["NEWCollabToolsHaveWorkedWith"].split(';') if pd.notnull(row['NEWCollabToolsHaveWorkedWith']) else []
        collab_worked_objects = []
        for obj in row_items:
            tb_obj = session.query(Collab).filter_by(name=obj).first()
            if obj and not tb_obj:
                tb_obj = Collab(name=obj)
                session.add(tb_obj)
            if tb_obj:
                collab_worked_objects.append(tb_obj)
    
        row_items = row["NEWCollabToolsWantToWorkWith"].split(';') if pd.notnull(row['NEWCollabToolsWantToWorkWith']) else []
        collab_want_objects = []
        for obj in row_items:
            tb_obj = session.query(Collab).filter_by(name=obj).first()
            if obj and not tb_obj:
                tb_obj = Collab(name=obj)
                session.add(tb_obj)
            if tb_obj:
                collab_want_objects.append(tb_obj)
    
        row_items = row["DatabaseHaveWorkedWith"].split(';') if pd.notnull(row['DatabaseHaveWorkedWith']) else []
        database_worked_objects = []
        for obj in row_items:
            tb_obj = session.query(Database).filter_by(name=obj).first()
            if obj and not tb_obj:
                tb_obj = Database(name=obj)
                session.add(tb_obj)
            if tb_obj:
                database_worked_objects.append(tb_obj)
                
        row_items = row["DatabaseWantToWorkWith"].split(';') if pd.notnull(row['DatabaseWantToWorkWith']) else []
        database_want_objects = []
        for obj in row_items:
            tb_obj = session.query(Database).filter_by(name=obj).first()
            if obj and not tb_obj:
                tb_obj = Database(name=obj)
                session.add(tb_obj)
            if tb_obj:
                database_want_objects.append(tb_obj)
    
        row_items = row["DevType"].split(';') if pd.notnull(row['DevType']) else []
        devtype_objects = []
        for obj in row_items:
            tb_obj = session.query(DevType).filter_by(name=obj).first()
            if obj and not tb_obj:
                tb_obj = DevType(name=obj)
                session.add(tb_obj)
            if tb_obj:
                devtype_objects.append(tb_obj)
                
        row_items = row["LanguageHaveWorkedWith"].split(';') if pd.notnull(row['LanguageHaveWorkedWith']) else []
        language_worked_objects = []
        for obj in row_items:
            tb_obj = session.query(Language).filter_by(name=obj).first()
            if obj and not tb_obj:
                tb_obj = Language(name=obj)
                session.add(tb_obj)
            if tb_obj:
                language_worked_objects.append(tb_obj)
                
        row_items = row["LanguageWantToWorkWith"].split(';') if pd.notnull(row['LanguageWantToWorkWith']) else []
        language_want_objects = []
        for obj in row_items:
            tb_obj = session.query(Language).filter_by(name=obj).first()
            if obj and not tb_obj:
                tb_obj = Language(name=obj)
                session.add(tb_obj)
            if tb_obj:
                language_want_objects.append(tb_obj)
    
        row_items = row["MiscTechHaveWorkedWith"].split(';') if pd.notnull(row['MiscTechHaveWorkedWith']) else []
        misc_tech_worked_objects = []
        for obj in row_items:
            tb_obj = session.query(MiscTech).filter_by(name=obj).first()
            if obj and not tb_obj:
                tb_obj = MiscTech(name=obj)
                session.add(tb_obj)
            if tb_obj:
                misc_tech_worked_objects.append(tb_obj)
    
        row_items = row["MiscTechWantToWorkWith"].split(';') if pd.notnull(row['MiscTechWantToWorkWith']) else []
        misc_tech_want_objects = []
        for obj in row_items:
            tb_obj = session.query(MiscTech).filter_by(name=obj).first()
            if obj and not tb_obj:
                tb_obj = MiscTech(name=obj)
                session.add(tb_obj)
            if tb_obj:
                misc_tech_want_objects.append(tb_obj)
    
        row_items = row["OpSys"].split(';') if pd.notnull(row['OpSys']) else []
        op_sys_objects = []
        for obj in row_items:
            tb_obj = session.query(OpSys).filter_by(name=obj).first()
            if obj and not tb_obj:
                tb_obj = OpSys(name=obj)
                session.add(tb_obj)
            if tb_obj:
                op_sys_objects.append(tb_obj)
    
        row_items = row["PlatformHaveWorkedWith"].split(';') if pd.notnull(row['PlatformHaveWorkedWith']) else []
        platform_worked_objects = []
        for obj in row_items:
            tb_obj = session.query(Platform).filter_by(name=obj).first()
            if obj and not tb_obj:
                tb_obj = Platform(name=obj)
                session.add(tb_obj)
            if tb_obj:
                platform_worked_objects.append(tb_obj)
    
        row_items = row["PlatformWantToWorkWith"].split(';') if pd.notnull(row['PlatformWantToWorkWith']) else []
        platform_want_objects = []
        for obj in row_items:
            tb_obj = session.query(Platform).filter_by(name=obj).first()
            if obj and not tb_obj:
                tb_obj = Platform(name=obj)
                session.add(tb_obj)
            if tb_obj:
                platform_want_objects.append(tb_obj)
    
        row_items = row["WebframeHaveWorkedWith"].split(';') if pd.notnull(row['WebframeHaveWorkedWith']) else []
        webframe_worked_objects = []
        for obj in row_items:
            tb_obj = session.query(WebFrame).filter_by(name=obj).first()
            if obj and not tb_obj:
                tb_obj = WebFrame(name=obj)
                session.add(tb_obj)
            if tb_obj:
                webframe_worked_objects.append(tb_obj)
    
        row_items = row["WebframeWantToWorkWith"].split(';') if pd.notnull(row['WebframeWantToWorkWith']) else []
        webframe_want_objects = []
        for obj in row_items:
            tb_obj = session.query(WebFrame).filter_by(name=obj).first()
            if obj and not tb_obj:
                tb_obj = WebFrame(name=obj)
                session.add(tb_obj)
            if tb_obj:
                webframe_want_objects.append(tb_obj)
        
        entry = Entry(
            year=csv[1], 
            age=row["Age"],
            coding_act=coding_act_objects,
            collab_worked=collab_worked_objects,
            collab_want=collab_want_objects,
            converted_compy=row["ConvertedCompYearly"],
            database_worked = database_worked_objects,
            database_want = database_want_objects,
            dev_type = devtype_objects,
            ed_level = row["EdLevel"],
            employment = row["Employment"],
            language_worked = language_worked_objects,
            language_want = language_want_objects,
            main_branch = row["MainBranch"],
            misc_tech_worked = misc_tech_worked_objects,
            misc_tech_want = misc_tech_want_objects,
            op_sys = op_sys_objects,
            org_size = row["OrgSize"],
            platform_worked = platform_worked_objects,
            platform_want = platform_want_objects,
            response_id = row["ResponseId"],
            webframe_worked = webframe_worked_objects,
            webframe_want = webframe_want_objects,
            years_code = row["YearsCode"],
            years_codepro = row["YearsCodePro"],
            
        )
        session.add(entry)
    
session.commit()
# Out:
# 2023-08-28 22:30:03,790 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-08-28 22:30:03,793 INFO sqlalchemy.engine.Engine SELECT codacts.id AS codacts_id, codacts.name AS codacts_name
# FROM codacts
# WHERE codacts.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,794 INFO sqlalchemy.engine.Engine [generated in 0.00090s] ('Hobby', 1, 0)
# 2023-08-28 22:30:03,797 INFO sqlalchemy.engine.Engine INSERT INTO codacts (name) VALUES (?)
# 2023-08-28 22:30:03,798 INFO sqlalchemy.engine.Engine [generated in 0.00059s] ('Hobby',)
# 2023-08-28 22:30:03,801 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,801 INFO sqlalchemy.engine.Engine [generated in 0.00068s] ('DynamoDB', 1, 0)
# 2023-08-28 22:30:03,803 INFO sqlalchemy.engine.Engine INSERT INTO databases (name) VALUES (?)
# 2023-08-28 22:30:03,804 INFO sqlalchemy.engine.Engine [generated in 0.00062s] ('DynamoDB',)
# 2023-08-28 22:30:03,805 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,806 INFO sqlalchemy.engine.Engine [cached since 0.005058s ago] ('Firebase', 1, 0)
# 2023-08-28 22:30:03,807 INFO sqlalchemy.engine.Engine INSERT INTO databases (name) VALUES (?)
# 2023-08-28 22:30:03,808 INFO sqlalchemy.engine.Engine [cached since 0.004537s ago] ('Firebase',)
# 2023-08-28 22:30:03,809 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,809 INFO sqlalchemy.engine.Engine [cached since 0.008585s ago] ('Microsoft SQL Server', 1, 0)
# 2023-08-28 22:30:03,811 INFO sqlalchemy.engine.Engine INSERT INTO databases (name) VALUES (?)
# 2023-08-28 22:30:03,812 INFO sqlalchemy.engine.Engine [cached since 0.008652s ago] ('Microsoft SQL Server',)
# 2023-08-28 22:30:03,813 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,814 INFO sqlalchemy.engine.Engine [cached since 0.01322s ago] ('MySQL', 1, 0)
# 2023-08-28 22:30:03,816 INFO sqlalchemy.engine.Engine INSERT INTO databases (name) VALUES (?)
# 2023-08-28 22:30:03,816 INFO sqlalchemy.engine.Engine [cached since 0.01318s ago] ('MySQL',)
# 2023-08-28 22:30:03,818 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,818 INFO sqlalchemy.engine.Engine [cached since 0.01754s ago] ('SQLite', 1, 0)
# 2023-08-28 22:30:03,820 INFO sqlalchemy.engine.Engine INSERT INTO databases (name) VALUES (?)
# 2023-08-28 22:30:03,820 INFO sqlalchemy.engine.Engine [cached since 0.01699s ago] ('SQLite',)
# 2023-08-28 22:30:03,821 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,822 INFO sqlalchemy.engine.Engine [cached since 0.02126s ago] ('DynamoDB', 1, 0)
# 2023-08-28 22:30:03,824 INFO sqlalchemy.engine.Engine SELECT devtypes.id AS devtypes_id, devtypes.name AS devtypes_name
# FROM devtypes
# WHERE devtypes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,825 INFO sqlalchemy.engine.Engine [generated in 0.00080s] ('Developer, full-stack', 1, 0)
# 2023-08-28 22:30:03,828 INFO sqlalchemy.engine.Engine INSERT INTO devtypes (name) VALUES (?)
# 2023-08-28 22:30:03,829 INFO sqlalchemy.engine.Engine [generated in 0.00085s] ('Developer, full-stack',)
# 2023-08-28 22:30:03,831 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,831 INFO sqlalchemy.engine.Engine [generated in 0.00059s] ('C#', 1, 0)
# 2023-08-28 22:30:03,833 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:03,834 INFO sqlalchemy.engine.Engine [generated in 0.00074s] ('C#',)
# 2023-08-28 22:30:03,835 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,835 INFO sqlalchemy.engine.Engine [cached since 0.004791s ago] ('HTML/CSS', 1, 0)
# 2023-08-28 22:30:03,837 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:03,837 INFO sqlalchemy.engine.Engine [cached since 0.004201s ago] ('HTML/CSS',)
# 2023-08-28 22:30:03,838 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,839 INFO sqlalchemy.engine.Engine [cached since 0.008143s ago] ('Java', 1, 0)
# 2023-08-28 22:30:03,840 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:03,840 INFO sqlalchemy.engine.Engine [cached since 0.00745s ago] ('Java',)
# 2023-08-28 22:30:03,841 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,842 INFO sqlalchemy.engine.Engine [cached since 0.01147s ago] ('JavaScript', 1, 0)
# 2023-08-28 22:30:03,843 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:03,844 INFO sqlalchemy.engine.Engine [cached since 0.01079s ago] ('JavaScript',)
# 2023-08-28 22:30:03,845 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,845 INFO sqlalchemy.engine.Engine [cached since 0.0148s ago] ('SQL', 1, 0)
# 2023-08-28 22:30:03,847 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:03,847 INFO sqlalchemy.engine.Engine [cached since 0.01411s ago] ('SQL',)
# 2023-08-28 22:30:03,848 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,849 INFO sqlalchemy.engine.Engine [cached since 0.0182s ago] ('TypeScript', 1, 0)
# 2023-08-28 22:30:03,850 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:03,851 INFO sqlalchemy.engine.Engine [cached since 0.01759s ago] ('TypeScript',)
# 2023-08-28 22:30:03,852 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,852 INFO sqlalchemy.engine.Engine [cached since 0.02152s ago] ('HTML/CSS', 1, 0)
# 2023-08-28 22:30:03,853 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,854 INFO sqlalchemy.engine.Engine [cached since 0.02315s ago] ('JavaScript', 1, 0)
# 2023-08-28 22:30:03,856 INFO sqlalchemy.engine.Engine SELECT misctechs.id AS misctechs_id, misctechs.name AS misctechs_name
# FROM misctechs
# WHERE misctechs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,856 INFO sqlalchemy.engine.Engine [generated in 0.00072s] ('.NET', 1, 0)
# 2023-08-28 22:30:03,858 INFO sqlalchemy.engine.Engine INSERT INTO misctechs (name) VALUES (?)
# 2023-08-28 22:30:03,858 INFO sqlalchemy.engine.Engine [generated in 0.00051s] ('.NET',)
# 2023-08-28 22:30:03,860 INFO sqlalchemy.engine.Engine SELECT misctechs.id AS misctechs_id, misctechs.name AS misctechs_name
# FROM misctechs
# WHERE misctechs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,860 INFO sqlalchemy.engine.Engine [cached since 0.004618s ago] ('.NET Core', 1, 0)
# 2023-08-28 22:30:03,862 INFO sqlalchemy.engine.Engine INSERT INTO misctechs (name) VALUES (?)
# 2023-08-28 22:30:03,862 INFO sqlalchemy.engine.Engine [cached since 0.004124s ago] ('.NET Core',)
# 2023-08-28 22:30:03,863 INFO sqlalchemy.engine.Engine SELECT misctechs.id AS misctechs_id, misctechs.name AS misctechs_name
# FROM misctechs
# WHERE misctechs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,864 INFO sqlalchemy.engine.Engine [cached since 0.007952s ago] ('Node.js', 1, 0)
# 2023-08-28 22:30:03,865 INFO sqlalchemy.engine.Engine INSERT INTO misctechs (name) VALUES (?)
# 2023-08-28 22:30:03,866 INFO sqlalchemy.engine.Engine [cached since 0.007617s ago] ('Node.js',)
# 2023-08-28 22:30:03,867 INFO sqlalchemy.engine.Engine SELECT misctechs.id AS misctechs_id, misctechs.name AS misctechs_name
# FROM misctechs
# WHERE misctechs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,867 INFO sqlalchemy.engine.Engine [cached since 0.01147s ago] ('Node.js', 1, 0)
# 2023-08-28 22:30:03,869 INFO sqlalchemy.engine.Engine SELECT opsys.id AS opsys_id, opsys.name AS opsys_name
# FROM opsys
# WHERE opsys.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,869 INFO sqlalchemy.engine.Engine [generated in 0.00053s] ('MacOS', 1, 0)
# 2023-08-28 22:30:03,872 INFO sqlalchemy.engine.Engine INSERT INTO opsys (name) VALUES (?)
# 2023-08-28 22:30:03,872 INFO sqlalchemy.engine.Engine [generated in 0.00072s] ('MacOS',)
# 2023-08-28 22:30:03,874 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,874 INFO sqlalchemy.engine.Engine [generated in 0.00056s] ('Android', 1, 0)
# 2023-08-28 22:30:03,876 INFO sqlalchemy.engine.Engine INSERT INTO platforms (name) VALUES (?)
# 2023-08-28 22:30:03,877 INFO sqlalchemy.engine.Engine [generated in 0.00073s] ('Android',)
# 2023-08-28 22:30:03,878 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,879 INFO sqlalchemy.engine.Engine [cached since 0.005166s ago] ('AWS', 1, 0)
# 2023-08-28 22:30:03,881 INFO sqlalchemy.engine.Engine INSERT INTO platforms (name) VALUES (?)
# 2023-08-28 22:30:03,882 INFO sqlalchemy.engine.Engine [cached since 0.006073s ago] ('AWS',)
# 2023-08-28 22:30:03,884 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,884 INFO sqlalchemy.engine.Engine [cached since 0.01025s ago] ('Microsoft Azure', 1, 0)
# 2023-08-28 22:30:03,886 INFO sqlalchemy.engine.Engine INSERT INTO platforms (name) VALUES (?)
# 2023-08-28 22:30:03,887 INFO sqlalchemy.engine.Engine [cached since 0.01092s ago] ('Microsoft Azure',)
# 2023-08-28 22:30:03,888 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,889 INFO sqlalchemy.engine.Engine [cached since 0.01529s ago] ('AWS', 1, 0)
# 2023-08-28 22:30:03,892 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,892 INFO sqlalchemy.engine.Engine [generated in 0.00066s] ('Angular/Angular.js', 1, 0)
# 2023-08-28 22:30:03,896 INFO sqlalchemy.engine.Engine INSERT INTO webframes (name) VALUES (?)
# 2023-08-28 22:30:03,896 INFO sqlalchemy.engine.Engine [generated in 0.00073s] ('Angular/Angular.js',)
# 2023-08-28 22:30:03,898 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,899 INFO sqlalchemy.engine.Engine [cached since 0.007013s ago] ('ASP.NET', 1, 0)
# 2023-08-28 22:30:03,900 INFO sqlalchemy.engine.Engine INSERT INTO webframes (name) VALUES (?)
# 2023-08-28 22:30:03,901 INFO sqlalchemy.engine.Engine [cached since 0.005222s ago] ('ASP.NET',)
# 2023-08-28 22:30:03,902 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,902 INFO sqlalchemy.engine.Engine [cached since 0.01078s ago] ('Express', 1, 0)
# 2023-08-28 22:30:03,904 INFO sqlalchemy.engine.Engine INSERT INTO webframes (name) VALUES (?)
# 2023-08-28 22:30:03,905 INFO sqlalchemy.engine.Engine [cached since 0.008963s ago] ('Express',)
# 2023-08-28 22:30:03,906 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,906 INFO sqlalchemy.engine.Engine [cached since 0.01467s ago] ('jQuery', 1, 0)
# 2023-08-28 22:30:03,908 INFO sqlalchemy.engine.Engine INSERT INTO webframes (name) VALUES (?)
# 2023-08-28 22:30:03,908 INFO sqlalchemy.engine.Engine [cached since 0.01285s ago] ('jQuery',)
# 2023-08-28 22:30:03,910 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,910 INFO sqlalchemy.engine.Engine [cached since 0.01857s ago] ('React.js', 1, 0)
# 2023-08-28 22:30:03,912 INFO sqlalchemy.engine.Engine INSERT INTO webframes (name) VALUES (?)
# 2023-08-28 22:30:03,912 INFO sqlalchemy.engine.Engine [cached since 0.01685s ago] ('React.js',)
# 2023-08-28 22:30:03,914 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,914 INFO sqlalchemy.engine.Engine [cached since 0.02263s ago] ('Express', 1, 0)
# 2023-08-28 22:30:03,916 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,916 INFO sqlalchemy.engine.Engine [cached since 0.02468s ago] ('React.js', 1, 0)
# 2023-08-28 22:30:03,927 INFO sqlalchemy.engine.Engine INSERT INTO entries (year, age, converted_compy, ed_level, employment, main_branch, org_size, response_id, years_code, years_codepro) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2023-08-28 22:30:03,928 INFO sqlalchemy.engine.Engine [generated in 0.00089s] (2019, 31.0, 31140.0, 'Some college/university study without earning a degree', 'Employed full-time', 'I am a developer by profession', '100 to 499 employees', 19, '14', '13')
# 2023-08-28 22:30:03,930 INFO sqlalchemy.engine.Engine INSERT INTO worked_codact_association (entry_id, codact_id) VALUES (?, ?)
# 2023-08-28 22:30:03,930 INFO sqlalchemy.engine.Engine [generated in 0.00068s] (1, 1)
# 2023-08-28 22:30:03,932 INFO sqlalchemy.engine.Engine INSERT INTO want_database_association (entry_id, database_id) VALUES (?, ?)
# 2023-08-28 22:30:03,932 INFO sqlalchemy.engine.Engine [generated in 0.00061s] (1, 1)
# 2023-08-28 22:30:03,934 INFO sqlalchemy.engine.Engine INSERT INTO worked_database_association (entry_id, database_id) VALUES (?, ?)
# 2023-08-28 22:30:03,934 INFO sqlalchemy.engine.Engine [generated in 0.00062s] [(1, 2), (1, 5), (1, 3), (1, 4), (1, 1)]
# 2023-08-28 22:30:03,936 INFO sqlalchemy.engine.Engine INSERT INTO worked_devtype_association (entry_id, devtype_id) VALUES (?, ?)
# 2023-08-28 22:30:03,937 INFO sqlalchemy.engine.Engine [generated in 0.00067s] (1, 1)
# 2023-08-28 22:30:03,938 INFO sqlalchemy.engine.Engine INSERT INTO want_language_association (entry_id, language_id) VALUES (?, ?)
# 2023-08-28 22:30:03,939 INFO sqlalchemy.engine.Engine [generated in 0.00057s] [(1, 2), (1, 4)]
# 2023-08-28 22:30:03,940 INFO sqlalchemy.engine.Engine INSERT INTO worked_language_association (entry_id, language_id) VALUES (?, ?)
# 2023-08-28 22:30:03,941 INFO sqlalchemy.engine.Engine [generated in 0.00066s] [(1, 1), (1, 2), (1, 3), (1, 4), (1, 5), (1, 6)]
# 2023-08-28 22:30:03,943 INFO sqlalchemy.engine.Engine INSERT INTO want_misctechs_association (entry_id, misctech_id) VALUES (?, ?)
# 2023-08-28 22:30:03,943 INFO sqlalchemy.engine.Engine [generated in 0.00094s] (1, 3)
# 2023-08-28 22:30:03,945 INFO sqlalchemy.engine.Engine INSERT INTO worked_misctech_association (entry_id, misctech_id) VALUES (?, ?)
# 2023-08-28 22:30:03,946 INFO sqlalchemy.engine.Engine [generated in 0.00068s] [(1, 1), (1, 2), (1, 3)]
# 2023-08-28 22:30:03,947 INFO sqlalchemy.engine.Engine INSERT INTO worked_opsys_association (entry_id, opsys_id) VALUES (?, ?)
# 2023-08-28 22:30:03,948 INFO sqlalchemy.engine.Engine [generated in 0.00053s] (1, 1)
# 2023-08-28 22:30:03,949 INFO sqlalchemy.engine.Engine INSERT INTO want_platform_association (entry_id, platform_id) VALUES (?, ?)
# 2023-08-28 22:30:03,949 INFO sqlalchemy.engine.Engine [generated in 0.00062s] (1, 2)
# 2023-08-28 22:30:03,951 INFO sqlalchemy.engine.Engine INSERT INTO worked_platform_association (entry_id, platform_id) VALUES (?, ?)
# 2023-08-28 22:30:03,952 INFO sqlalchemy.engine.Engine [generated in 0.00074s] [(1, 1), (1, 2), (1, 3)]
# 2023-08-28 22:30:03,953 INFO sqlalchemy.engine.Engine INSERT INTO want_webframe_association (entry_id, webframe_id) VALUES (?, ?)
# 2023-08-28 22:30:03,954 INFO sqlalchemy.engine.Engine [generated in 0.00060s] [(1, 3), (1, 5)]
# 2023-08-28 22:30:03,955 INFO sqlalchemy.engine.Engine INSERT INTO worked_webframe_association (entry_id, webframe_id) VALUES (?, ?)
# 2023-08-28 22:30:03,956 INFO sqlalchemy.engine.Engine [generated in 0.00088s] [(1, 1), (1, 2), (1, 3), (1, 4), (1, 5)]
# 2023-08-28 22:30:03,958 INFO sqlalchemy.engine.Engine SELECT codacts.id AS codacts_id, codacts.name AS codacts_name
# FROM codacts
# WHERE codacts.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,959 INFO sqlalchemy.engine.Engine [cached since 0.1654s ago] ('Hobby', 1, 0)
# 2023-08-28 22:30:03,961 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,962 INFO sqlalchemy.engine.Engine [cached since 0.161s ago] ('Microsoft SQL Server', 1, 0)
# 2023-08-28 22:30:03,964 INFO sqlalchemy.engine.Engine SELECT devtypes.id AS devtypes_id, devtypes.name AS devtypes_name
# FROM devtypes
# WHERE devtypes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,964 INFO sqlalchemy.engine.Engine [cached since 0.1402s ago] ('Developer, back-end', 1, 0)
# 2023-08-28 22:30:03,966 INFO sqlalchemy.engine.Engine INSERT INTO devtypes (name) VALUES (?)
# 2023-08-28 22:30:03,967 INFO sqlalchemy.engine.Engine [cached since 0.1391s ago] ('Developer, back-end',)
# 2023-08-28 22:30:03,968 INFO sqlalchemy.engine.Engine SELECT devtypes.id AS devtypes_id, devtypes.name AS devtypes_name
# FROM devtypes
# WHERE devtypes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,969 INFO sqlalchemy.engine.Engine [cached since 0.145s ago] ('Developer, front-end', 1, 0)
# 2023-08-28 22:30:03,971 INFO sqlalchemy.engine.Engine INSERT INTO devtypes (name) VALUES (?)
# 2023-08-28 22:30:03,971 INFO sqlalchemy.engine.Engine [cached since 0.1436s ago] ('Developer, front-end',)
# 2023-08-28 22:30:03,973 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,973 INFO sqlalchemy.engine.Engine [cached since 0.1429s ago] ('Bash/Shell/PowerShell', 1, 0)
# 2023-08-28 22:30:03,975 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:03,976 INFO sqlalchemy.engine.Engine [cached since 0.143s ago] ('Bash/Shell/PowerShell',)
# 2023-08-28 22:30:03,978 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,978 INFO sqlalchemy.engine.Engine [cached since 0.148s ago] ('C', 1, 0)
# 2023-08-28 22:30:03,980 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:03,981 INFO sqlalchemy.engine.Engine [cached since 0.148s ago] ('C',)
# 2023-08-28 22:30:03,982 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,983 INFO sqlalchemy.engine.Engine [cached since 0.1523s ago] ('C++', 1, 0)
# 2023-08-28 22:30:03,985 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:03,985 INFO sqlalchemy.engine.Engine [cached since 0.1521s ago] ('C++',)
# 2023-08-28 22:30:03,986 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,987 INFO sqlalchemy.engine.Engine [cached since 0.1564s ago] ('C#', 1, 0)
# 2023-08-28 22:30:03,988 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,989 INFO sqlalchemy.engine.Engine [cached since 0.1584s ago] ('Go', 1, 0)
# 2023-08-28 22:30:03,991 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:03,991 INFO sqlalchemy.engine.Engine [cached since 0.1583s ago] ('Go',)
# 2023-08-28 22:30:03,993 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,993 INFO sqlalchemy.engine.Engine [cached since 0.1627s ago] ('HTML/CSS', 1, 0)
# 2023-08-28 22:30:03,995 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,995 INFO sqlalchemy.engine.Engine [cached since 0.1649s ago] ('Java', 1, 0)
# 2023-08-28 22:30:03,997 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,997 INFO sqlalchemy.engine.Engine [cached since 0.1667s ago] ('JavaScript', 1, 0)
# 2023-08-28 22:30:03,998 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:03,999 INFO sqlalchemy.engine.Engine [cached since 0.1684s ago] ('Objective-C', 1, 0)
# 2023-08-28 22:30:04,001 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:04,001 INFO sqlalchemy.engine.Engine [cached since 0.1682s ago] ('Objective-C',)
# 2023-08-28 22:30:04,002 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,003 INFO sqlalchemy.engine.Engine [cached since 0.1722s ago] ('Python', 1, 0)
# 2023-08-28 22:30:04,004 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:04,005 INFO sqlalchemy.engine.Engine [cached since 0.1723s ago] ('Python',)
# 2023-08-28 22:30:04,006 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,007 INFO sqlalchemy.engine.Engine [cached since 0.1762s ago] ('SQL', 1, 0)
# 2023-08-28 22:30:04,008 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,009 INFO sqlalchemy.engine.Engine [cached since 0.1782s ago] ('Go', 1, 0)
# 2023-08-28 22:30:04,010 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,011 INFO sqlalchemy.engine.Engine [cached since 0.1805s ago] ('HTML/CSS', 1, 0)
# 2023-08-28 22:30:04,013 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,013 INFO sqlalchemy.engine.Engine [cached since 0.1826s ago] ('JavaScript', 1, 0)
# 2023-08-28 22:30:04,015 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,016 INFO sqlalchemy.engine.Engine [cached since 0.1853s ago] ('Kotlin', 1, 0)
# 2023-08-28 22:30:04,017 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:04,018 INFO sqlalchemy.engine.Engine [cached since 0.1851s ago] ('Kotlin',)
# 2023-08-28 22:30:04,019 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,020 INFO sqlalchemy.engine.Engine [cached since 0.1893s ago] ('Python', 1, 0)
# 2023-08-28 22:30:04,021 INFO sqlalchemy.engine.Engine SELECT misctechs.id AS misctechs_id, misctechs.name AS misctechs_name
# FROM misctechs
# WHERE misctechs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,022 INFO sqlalchemy.engine.Engine [cached since 0.1665s ago] ('.NET', 1, 0)
# 2023-08-28 22:30:04,024 INFO sqlalchemy.engine.Engine SELECT misctechs.id AS misctechs_id, misctechs.name AS misctechs_name
# FROM misctechs
# WHERE misctechs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,024 INFO sqlalchemy.engine.Engine [cached since 0.1685s ago] ('Node.js', 1, 0)
# 2023-08-28 22:30:04,026 INFO sqlalchemy.engine.Engine SELECT misctechs.id AS misctechs_id, misctechs.name AS misctechs_name
# FROM misctechs
# WHERE misctechs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,026 INFO sqlalchemy.engine.Engine [cached since 0.1707s ago] ('Node.js', 1, 0)
# 2023-08-28 22:30:04,028 INFO sqlalchemy.engine.Engine SELECT opsys.id AS opsys_id, opsys.name AS opsys_name
# FROM opsys
# WHERE opsys.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,029 INFO sqlalchemy.engine.Engine [cached since 0.1599s ago] ('MacOS', 1, 0)
# 2023-08-28 22:30:04,031 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,031 INFO sqlalchemy.engine.Engine [cached since 0.1574s ago] ('Android', 1, 0)
# 2023-08-28 22:30:04,033 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,034 INFO sqlalchemy.engine.Engine [cached since 0.1598s ago] ('AWS', 1, 0)
# 2023-08-28 22:30:04,035 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,035 INFO sqlalchemy.engine.Engine [cached since 0.1616s ago] ('Docker', 1, 0)
# 2023-08-28 22:30:04,037 INFO sqlalchemy.engine.Engine INSERT INTO platforms (name) VALUES (?)
# 2023-08-28 22:30:04,037 INFO sqlalchemy.engine.Engine [cached since 0.1611s ago] ('Docker',)
# 2023-08-28 22:30:04,038 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,039 INFO sqlalchemy.engine.Engine [cached since 0.1651s ago] ('iOS', 1, 0)
# 2023-08-28 22:30:04,040 INFO sqlalchemy.engine.Engine INSERT INTO platforms (name) VALUES (?)
# 2023-08-28 22:30:04,041 INFO sqlalchemy.engine.Engine [cached since 0.1646s ago] ('iOS',)
# 2023-08-28 22:30:04,042 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,043 INFO sqlalchemy.engine.Engine [cached since 0.1693s ago] ('Linux', 1, 0)
# 2023-08-28 22:30:04,045 INFO sqlalchemy.engine.Engine INSERT INTO platforms (name) VALUES (?)
# 2023-08-28 22:30:04,047 INFO sqlalchemy.engine.Engine [cached since 0.1704s ago] ('Linux',)
# 2023-08-28 22:30:04,048 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,049 INFO sqlalchemy.engine.Engine [cached since 0.1746s ago] ('MacOS', 1, 0)
# 2023-08-28 22:30:04,052 INFO sqlalchemy.engine.Engine INSERT INTO platforms (name) VALUES (?)
# 2023-08-28 22:30:04,053 INFO sqlalchemy.engine.Engine [cached since 0.1763s ago] ('MacOS',)
# 2023-08-28 22:30:04,054 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,055 INFO sqlalchemy.engine.Engine [cached since 0.1808s ago] ('Slack', 1, 0)
# 2023-08-28 22:30:04,057 INFO sqlalchemy.engine.Engine INSERT INTO platforms (name) VALUES (?)
# 2023-08-28 22:30:04,057 INFO sqlalchemy.engine.Engine [cached since 0.1811s ago] ('Slack',)
# 2023-08-28 22:30:04,059 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,060 INFO sqlalchemy.engine.Engine [cached since 0.1861s ago] ('Windows', 1, 0)
# 2023-08-28 22:30:04,062 INFO sqlalchemy.engine.Engine INSERT INTO platforms (name) VALUES (?)
# 2023-08-28 22:30:04,063 INFO sqlalchemy.engine.Engine [cached since 0.1867s ago] ('Windows',)
# 2023-08-28 22:30:04,064 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,065 INFO sqlalchemy.engine.Engine [cached since 0.1908s ago] ('AWS', 1, 0)
# 2023-08-28 22:30:04,066 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,067 INFO sqlalchemy.engine.Engine [cached since 0.1932s ago] ('Docker', 1, 0)
# 2023-08-28 22:30:04,069 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,070 INFO sqlalchemy.engine.Engine [cached since 0.1962s ago] ('Linux', 1, 0)
# 2023-08-28 22:30:04,072 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,072 INFO sqlalchemy.engine.Engine [cached since 0.1985s ago] ('MacOS', 1, 0)
# 2023-08-28 22:30:04,074 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,075 INFO sqlalchemy.engine.Engine [cached since 0.1831s ago] ('Django', 1, 0)
# 2023-08-28 22:30:04,077 INFO sqlalchemy.engine.Engine INSERT INTO webframes (name) VALUES (?)
# 2023-08-28 22:30:04,078 INFO sqlalchemy.engine.Engine [cached since 0.1822s ago] ('Django',)
# 2023-08-28 22:30:04,079 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,080 INFO sqlalchemy.engine.Engine [cached since 0.1884s ago] ('React.js', 1, 0)
# 2023-08-28 22:30:04,082 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,082 INFO sqlalchemy.engine.Engine [cached since 0.1906s ago] ('Spring', 1, 0)
# 2023-08-28 22:30:04,085 INFO sqlalchemy.engine.Engine INSERT INTO webframes (name) VALUES (?)
# 2023-08-28 22:30:04,085 INFO sqlalchemy.engine.Engine [cached since 0.1897s ago] ('Spring',)
# 2023-08-28 22:30:04,087 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,087 INFO sqlalchemy.engine.Engine [cached since 0.1958s ago] ('Django', 1, 0)
# 2023-08-28 22:30:04,089 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,090 INFO sqlalchemy.engine.Engine [cached since 0.198s ago] ('React.js', 1, 0)
# 2023-08-28 22:30:04,116 INFO sqlalchemy.engine.Engine INSERT INTO entries (year, age, converted_compy, ed_level, employment, main_branch, org_size, response_id, years_code, years_codepro) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2023-08-28 22:30:04,116 INFO sqlalchemy.engine.Engine [cached since 0.1899s ago] (2019, 36.0, 36060.0, 'Bachelor’s degree (BA, BS, B.Eng., etc.)', 'Employed full-time', 'I am a developer by profession', '10,000 or more employees', 87, '20', '8')
# 2023-08-28 22:30:04,118 INFO sqlalchemy.engine.Engine INSERT INTO worked_codact_association (entry_id, codact_id) VALUES (?, ?)
# 2023-08-28 22:30:04,119 INFO sqlalchemy.engine.Engine [cached since 0.1892s ago] (2, 1)
# 2023-08-28 22:30:04,120 INFO sqlalchemy.engine.Engine INSERT INTO worked_database_association (entry_id, database_id) VALUES (?, ?)
# 2023-08-28 22:30:04,120 INFO sqlalchemy.engine.Engine [generated in 0.00064s] (2, 3)
# 2023-08-28 22:30:04,122 INFO sqlalchemy.engine.Engine INSERT INTO worked_devtype_association (entry_id, devtype_id) VALUES (?, ?)
# 2023-08-28 22:30:04,123 INFO sqlalchemy.engine.Engine [generated in 0.00068s] [(2, 3), (2, 2)]
# 2023-08-28 22:30:04,124 INFO sqlalchemy.engine.Engine INSERT INTO want_language_association (entry_id, language_id) VALUES (?, ?)
# 2023-08-28 22:30:04,124 INFO sqlalchemy.engine.Engine [cached since 0.1864s ago] [(2, 10), (2, 2), (2, 4), (2, 13), (2, 12)]
# 2023-08-28 22:30:04,126 INFO sqlalchemy.engine.Engine INSERT INTO worked_language_association (entry_id, language_id) VALUES (?, ?)
# 2023-08-28 22:30:04,127 INFO sqlalchemy.engine.Engine [cached since 0.1867s ago] [(2, 7), (2, 8), (2, 9), (2, 1), (2, 10), (2, 2), (2, 3), (2, 4)  ... displaying 10 of 11 total bound parameter sets ...  (2, 12), (2, 5)]
# 2023-08-28 22:30:04,128 INFO sqlalchemy.engine.Engine INSERT INTO want_misctechs_association (entry_id, misctech_id) VALUES (?, ?)
# 2023-08-28 22:30:04,129 INFO sqlalchemy.engine.Engine [cached since 0.1862s ago] (2, 3)
# 2023-08-28 22:30:04,130 INFO sqlalchemy.engine.Engine INSERT INTO worked_misctech_association (entry_id, misctech_id) VALUES (?, ?)
# 2023-08-28 22:30:04,130 INFO sqlalchemy.engine.Engine [cached since 0.1853s ago] [(2, 1), (2, 3)]
# 2023-08-28 22:30:04,131 INFO sqlalchemy.engine.Engine INSERT INTO worked_opsys_association (entry_id, opsys_id) VALUES (?, ?)
# 2023-08-28 22:30:04,132 INFO sqlalchemy.engine.Engine [cached since 0.1852s ago] (2, 1)
# 2023-08-28 22:30:04,134 INFO sqlalchemy.engine.Engine INSERT INTO want_platform_association (entry_id, platform_id) VALUES (?, ?)
# 2023-08-28 22:30:04,134 INFO sqlalchemy.engine.Engine [generated in 0.00052s] [(2, 2), (2, 4), (2, 6), (2, 7)]
# 2023-08-28 22:30:04,135 INFO sqlalchemy.engine.Engine INSERT INTO worked_platform_association (entry_id, platform_id) VALUES (?, ?)
# 2023-08-28 22:30:04,136 INFO sqlalchemy.engine.Engine [cached since 0.1848s ago] [(2, 1), (2, 2), (2, 4), (2, 5), (2, 6), (2, 7), (2, 8), (2, 9)]
# 2023-08-28 22:30:04,137 INFO sqlalchemy.engine.Engine INSERT INTO want_webframe_association (entry_id, webframe_id) VALUES (?, ?)
# 2023-08-28 22:30:04,137 INFO sqlalchemy.engine.Engine [cached since 0.184s ago] [(2, 6), (2, 5)]
# 2023-08-28 22:30:04,138 INFO sqlalchemy.engine.Engine INSERT INTO worked_webframe_association (entry_id, webframe_id) VALUES (?, ?)
# 2023-08-28 22:30:04,139 INFO sqlalchemy.engine.Engine [cached since 0.1834s ago] [(2, 6), (2, 5), (2, 7)]
# 2023-08-28 22:30:04,142 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,143 INFO sqlalchemy.engine.Engine [generated in 0.00102s] ('Github', 1, 0)
# 2023-08-28 22:30:04,146 INFO sqlalchemy.engine.Engine INSERT INTO collabs (name) VALUES (?)
# 2023-08-28 22:30:04,146 INFO sqlalchemy.engine.Engine [generated in 0.00053s] ('Github',)
# 2023-08-28 22:30:04,148 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,149 INFO sqlalchemy.engine.Engine [cached since 0.006155s ago] ('Slack', 1, 0)
# 2023-08-28 22:30:04,151 INFO sqlalchemy.engine.Engine INSERT INTO collabs (name) VALUES (?)
# 2023-08-28 22:30:04,151 INFO sqlalchemy.engine.Engine [cached since 0.005741s ago] ('Slack',)
# 2023-08-28 22:30:04,153 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,153 INFO sqlalchemy.engine.Engine [cached since 0.01092s ago] ('Trello', 1, 0)
# 2023-08-28 22:30:04,155 INFO sqlalchemy.engine.Engine INSERT INTO collabs (name) VALUES (?)
# 2023-08-28 22:30:04,156 INFO sqlalchemy.engine.Engine [cached since 0.009968s ago] ('Trello',)
# 2023-08-28 22:30:04,157 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,157 INFO sqlalchemy.engine.Engine [cached since 0.01508s ago] ('Github', 1, 0)
# 2023-08-28 22:30:04,159 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,160 INFO sqlalchemy.engine.Engine [cached since 0.0177s ago] ('Slack', 1, 0)
# 2023-08-28 22:30:04,162 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,163 INFO sqlalchemy.engine.Engine [cached since 0.02031s ago] ('Trello', 1, 0)
# 2023-08-28 22:30:04,164 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,165 INFO sqlalchemy.engine.Engine [cached since 0.3641s ago] ('Microsoft SQL Server', 1, 0)
# 2023-08-28 22:30:04,166 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,167 INFO sqlalchemy.engine.Engine [cached since 0.3664s ago] ('Microsoft SQL Server', 1, 0)
# 2023-08-28 22:30:04,169 INFO sqlalchemy.engine.Engine SELECT devtypes.id AS devtypes_id, devtypes.name AS devtypes_name
# FROM devtypes
# WHERE devtypes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,170 INFO sqlalchemy.engine.Engine [cached since 0.3458s ago] ('Data or business analyst', 1, 0)
# 2023-08-28 22:30:04,172 INFO sqlalchemy.engine.Engine INSERT INTO devtypes (name) VALUES (?)
# 2023-08-28 22:30:04,172 INFO sqlalchemy.engine.Engine [cached since 0.3446s ago] ('Data or business analyst',)
# 2023-08-28 22:30:04,174 INFO sqlalchemy.engine.Engine SELECT devtypes.id AS devtypes_id, devtypes.name AS devtypes_name
# FROM devtypes
# WHERE devtypes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,175 INFO sqlalchemy.engine.Engine [cached since 0.3507s ago] ('Developer, back-end', 1, 0)
# 2023-08-28 22:30:04,177 INFO sqlalchemy.engine.Engine SELECT devtypes.id AS devtypes_id, devtypes.name AS devtypes_name
# FROM devtypes
# WHERE devtypes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,178 INFO sqlalchemy.engine.Engine [cached since 0.3538s ago] ('Product manager', 1, 0)
# 2023-08-28 22:30:04,180 INFO sqlalchemy.engine.Engine INSERT INTO devtypes (name) VALUES (?)
# 2023-08-28 22:30:04,181 INFO sqlalchemy.engine.Engine [cached since 0.353s ago] ('Product manager',)
# 2023-08-28 22:30:04,182 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,183 INFO sqlalchemy.engine.Engine [cached since 0.3528s ago] ('HTML/CSS', 1, 0)
# 2023-08-28 22:30:04,185 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,186 INFO sqlalchemy.engine.Engine [cached since 0.3558s ago] ('Python', 1, 0)
# 2023-08-28 22:30:04,188 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,189 INFO sqlalchemy.engine.Engine [cached since 0.3583s ago] ('R', 1, 0)
# 2023-08-28 22:30:04,191 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:04,192 INFO sqlalchemy.engine.Engine [cached since 0.3587s ago] ('R',)
# 2023-08-28 22:30:04,193 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,194 INFO sqlalchemy.engine.Engine [cached since 0.3637s ago] ('SQL', 1, 0)
# 2023-08-28 22:30:04,196 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,197 INFO sqlalchemy.engine.Engine [cached since 0.366s ago] ('VBA', 1, 0)
# 2023-08-28 22:30:04,200 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:04,201 INFO sqlalchemy.engine.Engine [cached since 0.3675s ago] ('VBA',)
# 2023-08-28 22:30:04,202 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,203 INFO sqlalchemy.engine.Engine [cached since 0.3725s ago] ('HTML/CSS', 1, 0)
# 2023-08-28 22:30:04,205 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,206 INFO sqlalchemy.engine.Engine [cached since 0.3751s ago] ('Java', 1, 0)
# 2023-08-28 22:30:04,208 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,208 INFO sqlalchemy.engine.Engine [cached since 0.3777s ago] ('JavaScript', 1, 0)
# 2023-08-28 22:30:04,210 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,211 INFO sqlalchemy.engine.Engine [cached since 0.3803s ago] ('Python', 1, 0)
# 2023-08-28 22:30:04,213 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,213 INFO sqlalchemy.engine.Engine [cached since 0.3829s ago] ('R', 1, 0)
# 2023-08-28 22:30:04,215 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,215 INFO sqlalchemy.engine.Engine [cached since 0.3849s ago] ('SQL', 1, 0)
# 2023-08-28 22:30:04,217 INFO sqlalchemy.engine.Engine SELECT opsys.id AS opsys_id, opsys.name AS opsys_name
# FROM opsys
# WHERE opsys.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,217 INFO sqlalchemy.engine.Engine [cached since 0.3484s ago] ('Windows', 1, 0)
# 2023-08-28 22:30:04,219 INFO sqlalchemy.engine.Engine INSERT INTO opsys (name) VALUES (?)
# 2023-08-28 22:30:04,220 INFO sqlalchemy.engine.Engine [cached since 0.3482s ago] ('Windows',)
# 2023-08-28 22:30:04,221 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,221 INFO sqlalchemy.engine.Engine [cached since 0.3473s ago] ('Windows', 1, 0)
# 2023-08-28 22:30:04,222 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,223 INFO sqlalchemy.engine.Engine [cached since 0.3491s ago] ('Linux', 1, 0)
# 2023-08-28 22:30:04,225 INFO sqlalchemy.engine.Engine SELECT platforms.id AS platforms_id, platforms.name AS platforms_name
# FROM platforms
# WHERE platforms.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,225 INFO sqlalchemy.engine.Engine [cached since 0.3514s ago] ('Windows', 1, 0)
# 2023-08-28 22:30:04,230 INFO sqlalchemy.engine.Engine INSERT INTO entries (year, age, converted_compy, ed_level, employment, main_branch, org_size, response_id, years_code, years_codepro) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2023-08-28 22:30:04,231 INFO sqlalchemy.engine.Engine [cached since 0.3047s ago] (2020, 32.0, 55893.0, 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Employed full-time', 'I am a developer by profession', '10 to 19 employees', 44, '10', '6')
# 2023-08-28 22:30:04,233 INFO sqlalchemy.engine.Engine INSERT INTO want_collab_association (entry_id, collab_id) VALUES (?, ?)
# 2023-08-28 22:30:04,234 INFO sqlalchemy.engine.Engine [generated in 0.00062s] [(3, 1), (3, 2), (3, 3)]
# 2023-08-28 22:30:04,235 INFO sqlalchemy.engine.Engine INSERT INTO worked_collab_association (entry_id, collab_id) VALUES (?, ?)
# 2023-08-28 22:30:04,236 INFO sqlalchemy.engine.Engine [generated in 0.00060s] [(3, 1), (3, 2), (3, 3)]
# 2023-08-28 22:30:04,237 INFO sqlalchemy.engine.Engine INSERT INTO want_database_association (entry_id, database_id) VALUES (?, ?)
# 2023-08-28 22:30:04,237 INFO sqlalchemy.engine.Engine [cached since 0.3059s ago] (3, 3)
# 2023-08-28 22:30:04,238 INFO sqlalchemy.engine.Engine INSERT INTO worked_database_association (entry_id, database_id) VALUES (?, ?)
# 2023-08-28 22:30:04,239 INFO sqlalchemy.engine.Engine [cached since 0.1192s ago] (3, 3)
# 2023-08-28 22:30:04,240 INFO sqlalchemy.engine.Engine INSERT INTO worked_devtype_association (entry_id, devtype_id) VALUES (?, ?)
# 2023-08-28 22:30:04,240 INFO sqlalchemy.engine.Engine [cached since 0.1182s ago] [(3, 4), (3, 2), (3, 5)]
# 2023-08-28 22:30:04,241 INFO sqlalchemy.engine.Engine INSERT INTO want_language_association (entry_id, language_id) VALUES (?, ?)
# 2023-08-28 22:30:04,242 INFO sqlalchemy.engine.Engine [cached since 0.3035s ago] [(3, 2), (3, 3), (3, 4), (3, 12), (3, 14), (3, 5)]
# 2023-08-28 22:30:04,243 INFO sqlalchemy.engine.Engine INSERT INTO worked_language_association (entry_id, language_id) VALUES (?, ?)
# 2023-08-28 22:30:04,244 INFO sqlalchemy.engine.Engine [cached since 0.3034s ago] [(3, 2), (3, 12), (3, 14), (3, 5), (3, 15)]
# 2023-08-28 22:30:04,245 INFO sqlalchemy.engine.Engine INSERT INTO worked_opsys_association (entry_id, opsys_id) VALUES (?, ?)
# 2023-08-28 22:30:04,245 INFO sqlalchemy.engine.Engine [cached since 0.2983s ago] (3, 2)
# 2023-08-28 22:30:04,246 INFO sqlalchemy.engine.Engine INSERT INTO want_platform_association (entry_id, platform_id) VALUES (?, ?)
# 2023-08-28 22:30:04,247 INFO sqlalchemy.engine.Engine [cached since 0.1136s ago] [(3, 6), (3, 9)]
# 2023-08-28 22:30:04,249 INFO sqlalchemy.engine.Engine INSERT INTO worked_platform_association (entry_id, platform_id) VALUES (?, ?)
# 2023-08-28 22:30:04,249 INFO sqlalchemy.engine.Engine [generated in 0.00060s] (3, 9)
# 2023-08-28 22:30:04,251 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,252 INFO sqlalchemy.engine.Engine [cached since 0.1094s ago] ('Github', 1, 0)
# 2023-08-28 22:30:04,253 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,254 INFO sqlalchemy.engine.Engine [cached since 0.112s ago] ('Slack', 1, 0)
# 2023-08-28 22:30:04,256 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:04,256 INFO sqlalchemy.engine.Engine [cached since 0.114s ago] ('Trello', 1, 0)
# 2023-08-28 22:30:04,258 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# ...
# 2023-08-28 22:30:05,208 INFO sqlalchemy.engine.Engine INSERT INTO codacts (name) VALUES (?)
# 2023-08-28 22:30:05,209 INFO sqlalchemy.engine.Engine [cached since 1.412s ago] ('Freelance/contract work',)
# 2023-08-28 22:30:05,211 INFO sqlalchemy.engine.Engine SELECT codacts.id AS codacts_id, codacts.name AS codacts_name
# FROM codacts
# WHERE codacts.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,211 INFO sqlalchemy.engine.Engine [cached since 1.418s ago] ('School or academic work', 1, 0)
# 2023-08-28 22:30:05,213 INFO sqlalchemy.engine.Engine INSERT INTO codacts (name) VALUES (?)
# 2023-08-28 22:30:05,213 INFO sqlalchemy.engine.Engine [cached since 1.416s ago] ('School or academic work',)
# 2023-08-28 22:30:05,214 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,215 INFO sqlalchemy.engine.Engine [cached since 1.073s ago] ('Jupyter Notebook/JupyterLab', 1, 0)
# 2023-08-28 22:30:05,217 INFO sqlalchemy.engine.Engine INSERT INTO collabs (name) VALUES (?)
# 2023-08-28 22:30:05,217 INFO sqlalchemy.engine.Engine [cached since 1.071s ago] ('Jupyter Notebook/JupyterLab',)
# 2023-08-28 22:30:05,218 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,219 INFO sqlalchemy.engine.Engine [cached since 1.076s ago] ('Visual Studio Code', 1, 0)
# 2023-08-28 22:30:05,220 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,221 INFO sqlalchemy.engine.Engine [cached since 1.078s ago] ('IntelliJ IDEA', 1, 0)
# 2023-08-28 22:30:05,222 INFO sqlalchemy.engine.Engine INSERT INTO collabs (name) VALUES (?)
# 2023-08-28 22:30:05,222 INFO sqlalchemy.engine.Engine [cached since 1.077s ago] ('IntelliJ IDEA',)
# 2023-08-28 22:30:05,224 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,224 INFO sqlalchemy.engine.Engine [cached since 1.082s ago] ('Jupyter Notebook/JupyterLab', 1, 0)
# 2023-08-28 22:30:05,225 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,226 INFO sqlalchemy.engine.Engine [cached since 1.084s ago] ('Neovim', 1, 0)
# 2023-08-28 22:30:05,227 INFO sqlalchemy.engine.Engine INSERT INTO collabs (name) VALUES (?)
# 2023-08-28 22:30:05,228 INFO sqlalchemy.engine.Engine [cached since 1.082s ago] ('Neovim',)
# 2023-08-28 22:30:05,229 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,230 INFO sqlalchemy.engine.Engine [cached since 1.087s ago] ('Vim', 1, 0)
# 2023-08-28 22:30:05,231 INFO sqlalchemy.engine.Engine SELECT collabs.id AS collabs_id, collabs.name AS collabs_name
# FROM collabs
# WHERE collabs.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,231 INFO sqlalchemy.engine.Engine [cached since 1.089s ago] ('Visual Studio Code', 1, 0)
# 2023-08-28 22:30:05,233 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,233 INFO sqlalchemy.engine.Engine [cached since 1.432s ago] ('MySQL', 1, 0)
# 2023-08-28 22:30:05,234 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,235 INFO sqlalchemy.engine.Engine [cached since 1.434s ago] ('PostgreSQL', 1, 0)
# 2023-08-28 22:30:05,236 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,237 INFO sqlalchemy.engine.Engine [cached since 1.436s ago] ('Cassandra', 1, 0)
# 2023-08-28 22:30:05,238 INFO sqlalchemy.engine.Engine INSERT INTO databases (name) VALUES (?)
# 2023-08-28 22:30:05,239 INFO sqlalchemy.engine.Engine [cached since 1.435s ago] ('Cassandra',)
# 2023-08-28 22:30:05,240 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,240 INFO sqlalchemy.engine.Engine [cached since 1.439s ago] ('MongoDB', 1, 0)
# 2023-08-28 22:30:05,241 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,242 INFO sqlalchemy.engine.Engine [cached since 1.441s ago] ('MySQL', 1, 0)
# 2023-08-28 22:30:05,243 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,243 INFO sqlalchemy.engine.Engine [cached since 1.442s ago] ('Neo4J', 1, 0)
# 2023-08-28 22:30:05,244 INFO sqlalchemy.engine.Engine INSERT INTO databases (name) VALUES (?)
# 2023-08-28 22:30:05,245 INFO sqlalchemy.engine.Engine [cached since 1.441s ago] ('Neo4J',)
# 2023-08-28 22:30:05,246 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,246 INFO sqlalchemy.engine.Engine [cached since 1.445s ago] ('PostgreSQL', 1, 0)
# 2023-08-28 22:30:05,247 INFO sqlalchemy.engine.Engine SELECT databases.id AS databases_id, databases.name AS databases_name
# FROM databases
# WHERE databases.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,248 INFO sqlalchemy.engine.Engine [cached since 1.447s ago] ('Redis', 1, 0)
# 2023-08-28 22:30:05,249 INFO sqlalchemy.engine.Engine SELECT devtypes.id AS devtypes_id, devtypes.name AS devtypes_name
# FROM devtypes
# WHERE devtypes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,249 INFO sqlalchemy.engine.Engine [cached since 1.425s ago] ('Developer, full-stack', 1, 0)
# 2023-08-28 22:30:05,250 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,251 INFO sqlalchemy.engine.Engine [cached since 1.42s ago] ('Bash/Shell (all shells)', 1, 0)
# 2023-08-28 22:30:05,252 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,253 INFO sqlalchemy.engine.Engine [cached since 1.422s ago] ('HTML/CSS', 1, 0)
# 2023-08-28 22:30:05,254 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,254 INFO sqlalchemy.engine.Engine [cached since 1.424s ago] ('JavaScript', 1, 0)
# 2023-08-28 22:30:05,256 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,256 INFO sqlalchemy.engine.Engine [cached since 1.425s ago] ('PHP', 1, 0)
# 2023-08-28 22:30:05,257 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,258 INFO sqlalchemy.engine.Engine [cached since 1.427s ago] ('SQL', 1, 0)
# 2023-08-28 22:30:05,259 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,259 INFO sqlalchemy.engine.Engine [cached since 1.429s ago] ('Bash/Shell (all shells)', 1, 0)
# 2023-08-28 22:30:05,261 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,261 INFO sqlalchemy.engine.Engine [cached since 1.431s ago] ('Dart', 1, 0)
# 2023-08-28 22:30:05,262 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,263 INFO sqlalchemy.engine.Engine [cached since 1.432s ago] ('Go', 1, 0)
# 2023-08-28 22:30:05,264 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,264 INFO sqlalchemy.engine.Engine [cached since 1.434s ago] ('HTML/CSS', 1, 0)
# 2023-08-28 22:30:05,266 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,266 INFO sqlalchemy.engine.Engine [cached since 1.436s ago] ('Java', 1, 0)
# 2023-08-28 22:30:05,267 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,267 INFO sqlalchemy.engine.Engine [cached since 1.437s ago] ('JavaScript', 1, 0)
# 2023-08-28 22:30:05,269 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,269 INFO sqlalchemy.engine.Engine [cached since 1.439s ago] ('Kotlin', 1, 0)
# 2023-08-28 22:30:05,270 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,270 INFO sqlalchemy.engine.Engine [cached since 1.44s ago] ('PHP', 1, 0)
# 2023-08-28 22:30:05,272 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,272 INFO sqlalchemy.engine.Engine [cached since 1.441s ago] ('R', 1, 0)
# 2023-08-28 22:30:05,273 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,274 INFO sqlalchemy.engine.Engine [cached since 1.443s ago] ('Rust', 1, 0)
# 2023-08-28 22:30:05,275 INFO sqlalchemy.engine.Engine INSERT INTO languages (name) VALUES (?)
# 2023-08-28 22:30:05,276 INFO sqlalchemy.engine.Engine [cached since 1.443s ago] ('Rust',)
# 2023-08-28 22:30:05,277 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,277 INFO sqlalchemy.engine.Engine [cached since 1.447s ago] ('SQL', 1, 0)
# 2023-08-28 22:30:05,279 INFO sqlalchemy.engine.Engine SELECT languages.id AS languages_id, languages.name AS languages_name
# FROM languages
# WHERE languages.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,279 INFO sqlalchemy.engine.Engine [cached since 1.449s ago] ('TypeScript', 1, 0)
# 2023-08-28 22:30:05,281 INFO sqlalchemy.engine.Engine SELECT opsys.id AS opsys_id, opsys.name AS opsys_name
# FROM opsys
# WHERE opsys.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,281 INFO sqlalchemy.engine.Engine [cached since 1.412s ago] ('Fedora', 1, 0)
# 2023-08-28 22:30:05,283 INFO sqlalchemy.engine.Engine INSERT INTO opsys (name) VALUES (?)
# 2023-08-28 22:30:05,284 INFO sqlalchemy.engine.Engine [cached since 1.412s ago] ('Fedora',)
# 2023-08-28 22:30:05,285 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,285 INFO sqlalchemy.engine.Engine [cached since 1.394s ago] ('jQuery', 1, 0)
# 2023-08-28 22:30:05,287 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,287 INFO sqlalchemy.engine.Engine [cached since 1.396s ago] ('Laravel', 1, 0)
# 2023-08-28 22:30:05,289 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,289 INFO sqlalchemy.engine.Engine [cached since 1.398s ago] ('Next.js', 1, 0)
# 2023-08-28 22:30:05,291 INFO sqlalchemy.engine.Engine SELECT webframes.id AS webframes_id, webframes.name AS webframes_name
# FROM webframes
# WHERE webframes.name = ?
#  LIMIT ? OFFSET ?
# 2023-08-28 22:30:05,291 INFO sqlalchemy.engine.Engine [cached since 1.4s ago] ('Vue.js', 1, 0)
# 2023-08-28 22:30:05,297 INFO sqlalchemy.engine.Engine INSERT INTO entries (year, age, converted_compy, ed_level, employment, main_branch, org_size, response_id, years_code, years_codepro) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2023-08-28 22:30:05,298 INFO sqlalchemy.engine.Engine [cached since 1.372s ago] (2023, '35-44 years old', 24345.0, 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Employed, full-time', 'I am a developer by profession', '1,000 to 4,999 employees', 89, '20', '14')
# 2023-08-28 22:30:05,299 INFO sqlalchemy.engine.Engine INSERT INTO worked_codact_association (entry_id, codact_id) VALUES (?, ?)
# 2023-08-28 22:30:05,300 INFO sqlalchemy.engine.Engine [cached since 0.2543s ago] [(10, 1), (10, 5), (10, 4), (10, 3)]
# 2023-08-28 22:30:05,301 INFO sqlalchemy.engine.Engine INSERT INTO want_collab_association (entry_id, collab_id) VALUES (?, ?)
# 2023-08-28 22:30:05,302 INFO sqlalchemy.engine.Engine [cached since 1.068s ago] [(10, 12), (10, 6), (10, 14), (10, 8), (10, 13)]
# 2023-08-28 22:30:05,303 INFO sqlalchemy.engine.Engine INSERT INTO worked_collab_association (entry_id, collab_id) VALUES (?, ?)
# 2023-08-28 22:30:05,303 INFO sqlalchemy.engine.Engine [cached since 1.068s ago] [(10, 12), (10, 8)]
# 2023-08-28 22:30:05,304 INFO sqlalchemy.engine.Engine INSERT INTO want_database_association (entry_id, database_id) VALUES (?, ?)
# 2023-08-28 22:30:05,305 INFO sqlalchemy.engine.Engine [cached since 0.754s ago] [(10, 12), (10, 11), (10, 8), (10, 4), (10, 13), (10, 6)]
# 2023-08-28 22:30:05,306 INFO sqlalchemy.engine.Engine INSERT INTO worked_database_association (entry_id, database_id) VALUES (?, ?)
# 2023-08-28 22:30:05,306 INFO sqlalchemy.engine.Engine [cached since 1.372s ago] [(10, 4), (10, 6)]
# 2023-08-28 22:30:05,307 INFO sqlalchemy.engine.Engine INSERT INTO worked_devtype_association (entry_id, devtype_id) VALUES (?, ?)
# 2023-08-28 22:30:05,309 INFO sqlalchemy.engine.Engine [cached since 1.373s ago] (10, 1)
# 2023-08-28 22:30:05,310 INFO sqlalchemy.engine.Engine INSERT INTO want_language_association (entry_id, language_id) VALUES (?, ?)
# 2023-08-28 22:30:05,311 INFO sqlalchemy.engine.Engine [cached since 1.373s ago] [(10, 25), (10, 24), (10, 10), (10, 2), (10, 3), (10, 4), (10, 13), (10, 16)  ... displaying 10 of 12 total bound parameter sets ...  (10, 5), (10, 6)]
# 2023-08-28 22:30:05,312 INFO sqlalchemy.engine.Engine INSERT INTO worked_language_association (entry_id, language_id) VALUES (?, ?)
# 2023-08-28 22:30:05,312 INFO sqlalchemy.engine.Engine [cached since 1.372s ago] [(10, 25), (10, 2), (10, 4), (10, 16), (10, 5)]
# 2023-08-28 22:30:05,313 INFO sqlalchemy.engine.Engine INSERT INTO worked_opsys_association (entry_id, opsys_id) VALUES (?, ?)
# 2023-08-28 22:30:05,314 INFO sqlalchemy.engine.Engine [cached since 1.367s ago] (10, 6)
# 2023-08-28 22:30:05,315 INFO sqlalchemy.engine.Engine INSERT INTO want_webframe_association (entry_id, webframe_id) VALUES (?, ?)
# 2023-08-28 22:30:05,316 INFO sqlalchemy.engine.Engine [cached since 1.362s ago] [(10, 8), (10, 15), (10, 16)]
# 2023-08-28 22:30:05,316 INFO sqlalchemy.engine.Engine INSERT INTO worked_webframe_association (entry_id, webframe_id) VALUES (?, ?)
# 2023-08-28 22:30:05,317 INFO sqlalchemy.engine.Engine [cached since 0.4398s ago] (10, 4)
# 2023-08-28 22:30:05,318 INFO sqlalchemy.engine.Engine COMMIT
